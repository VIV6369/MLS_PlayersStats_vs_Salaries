# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

stats = pd.read_csv("MLS_pl_2021_stats_w_2022_salaries.csv")

stats.head()
# Out:
#                    name club_abb              club  2021 guaranteed comp.  \
# 0  Valentin Castellanos      NYC     New York City               776000.0
# 1            Ola Kamara       DC         DC United               420000.0
# 2      Javier Hernandez       LA         LA Galaxy              6000000.0
# 3          Raul Ruidiaz      SEA  Seattle Sounders              2100000.0
# 4        Damir Kreilach      RSL    Real Salt Lake              1350000.0
#
#    2022 guar. comp.    position   birth_city birth_country  height, cm  \
# 0         1076000.0     Forward      Mendoza     Argentina       178.0
# 1         1520000.0     Forward          NaN           NaN       185.0
# 2         7443750.0     Forward  Guadalajara        Mexico       175.0
# 3         3201120.0     Forward         Lima          Peru       169.0
# 4         1762572.0  Midfielder      Vukovar       Croatia       186.0
#
#    weight, kg  ... accurate_goal_kicks  dive_catch  inaccurate_goal_kicks  \
# 0        70.0  ...                   0           0                      0
# 1        82.0  ...                   0           0                      0
# 2        73.0  ...                   0           0                      0
# 3        65.0  ...                   0           0                      0
# 4        79.0  ...                   0           0                      0
#
#    penalty_faced  pen_goals_conceded  punches  drops  good_claim  saves_per  \
# 0              0                   3        0      0           0        0.0
# 1              0                   2        0      0           0        0.0
# 2              0                   3        0      0           0        0.0
# 3              0                   3        0      0           0        0.0
# 4              0                   3        0      0           0        0.0
#
#    goals_against_average
# 0                   0.95
# 1                   1.43
# 2                   1.40
# 3                   0.92
# 4                   1.50
#
# [5 rows x 109 columns]

# %% [markdown]
# #### Stats description
#
# * name
#         - player's name
# * club_abb
#         - club's abbreviation
# * club
#         - club's name
# * guaranteed comp.
#         - The Annual Average Guaranteed Compensation (Guaranteed Comp) number includes a player's base salary and all signing and guaranteed bonuses annualized over the term of the player's contract, including option years
# * position
#         - field position
# * birth_city
#         - birth city
# * birth_country
#         - birth country
# * height, cm
#         - height in cm
# * weight, kg
#         - weight in kg
# * foot
#         - main foot
# * games_played
#         - number of games player played within season
# * game_started
#         - number of games player started in starting lineup
# * mins
#         - total number of minutes on the field within season
# * sub_on
#         - came on as substitute
# * total_sub_off
#         - total number was substituted
# * total_wins
#         - total wins
# * total_losses
#         - total losses
# * total_draws
#         - total draws
# * goals
#         - scored goals
# * goal_conversion_per
#         - conversion rate of goals scored to number of shots taken
# * assist
#         - goal assists this season
# * accurate_back_zone_pass
#         - a pass that is successful and ends in a player’s own half of the pitch
# * failed_back_zone_pass
#         - a pass that is failed and ends in a player’s own half of the pitch
# * accurate_cross
#         - a successful ball played from a wide position intending to reach a teammate in a specific area in front of the goal
# * failed_cross
#         - a failed ball played from a wide position intending to reach a teammate in a specific area in front of the goal
# * accurate_cross_per
#         - a percentage of successful crosses
# * accurate_cross_nocorner
#         - accurate crosses (including freekicks but excluding corners)
# * failed_cross_nocorner
#         - failed crosses (including freekicks but excluding corners)
# * accurate_fwd_zone_pass
#         - an accurate pass that ends in the attacking half of the pitch
# * failed_fwd_zone_pass
#         - failed pass that ends in the attacking half of the pitch
# * accurate_fwd_zone_pass_per
#         - a percentage of accurate pass that ends in the attacking half of the pitch
# * accurate_launches
#         - long ball played forward without an obvious target but successfully finds a team-mate
# * failed_launches
#         - long ball played forward without an obvious target that doesn't find a team-mate
# * accurate_layoffs
#         - a successful pass by a forward who has received the ball with his back to goal and then plays the ball back towards team-mates
# * failed_layoffs
#         - failed pass by a forward who has received the ball with his back to goal and then plays the ball back towards team-mates
# * accurate_long_balls
#         - accurate passes further than 35 yards/32 meters (excluding throw-ins, crosses, keeper throws)
# * failed_long_balls
#         - failed passes further than 35 yards/32 meters (excluding throw-ins, crosses, keeper throws)
# * accurate_pass
#         - passes completed from one player to another (excluding throw-ins, keeper throws and crosses)
# * accurate_pass_per
#         - percentage of accurate passes completed from one player to another (excluding throw-ins, keeper throws and crosses)
# * accurate_throws
#         - all accurate throw-ins
# * failed_throws
#         - all failed throw-ins
# * aerial_lost
#         - failed aerial duels. Definition of an aerial duel: Two outfield players compete for the ball, with either both players jumping or only one jumping and the other contesting the header by making it difficult to win, where one player wins the contest with a header. In the case of an outfield player and a goalkeeper competing for the ball where the goalkeeper punches it clear, this is also classed as an aerial duel
# * aerial_won
#         - successful aerial duels
# * head_goal
#         - a goal scored by striking the ball with the head
# * inside_box_goal
#         - goal from a shot inside the box
# * outside_box_goal
#         - goal from a shot outside the box
# * left_foot_goal
#         - goal from a shot with left foot
# * right_foot_goal
#         - goal from a shot with right foot
# * penalty_goal
#         - penalty kick goal
# * attempted_tackle_foul
#         - a foul event with "attempted tackles" qualifier assigned
# * fwd_pass
#         - a pass forward (excludes throw-ins, keeper throws, goal kicks and crosses)
# * back_pass
#         - a pass backward (excludes throw-ins, keeper throws, goal kicks and crosses)
# * ball_recovery
#         - a player takes possession of a loose ball
# * successful_dribble
#         - total dribbles where player beats an opponent
# * failed_dribble
#         - failed dribbles where player losses possession of the ball
# * successful_short_pass
#         - a successful short distance (under 35 yards/32 meters) pass
# * failed_short_pass
#         - failed short distance (under 35 yards/32 meters) pass
# * fk_foul_lost
#         - free kicks conceded to the opposition via fouls, handballs, dangerous play, etc
# * fk_foul_won
#         - free kicks won when fouled or as a result of dangerous play by the opposition (does not include handball or penalties)
# * ground_duel_lost
#         - lost duel when two players contest a ball on the ground
# * ground_duel_won
#         - won duel when two players contest a ball on the ground
# * hand_ball
#         - number of hand balls
# * won_tackle
#         - total tackles won by the player (winning possession or putting the ball out of play)
# * lost_tackle
#         - total tackles lost by the player (does not get possession or putting the ball out of play)
# * total_tackle
#         - total number of tackles
# * tackle_success_per
#         - a percentage of successful tackle
# * ontarget_scoring_att
#         - shot on target (i.e. applies for a shot that was not blocked, and did not hit woodwork, but may have been saved off the line by a player on the defending team)
# * total_scoring_att
#         - total number of shots at goal (excludes own goals)
# * accurate_shooting_per
#         - a percentage of shots that hit target (i.e. applies for a shot that was not blocked, and did not hit woodwork, but may have been saved off the line by a player on the defending team)
# * successful_open_play_pass
#         - any type of pass to a teammate in open play ("Open play" in soccer refers to any action that occurs during a match that is not a set play, such as a free kick, corner kick, or penalty kick. It refers to the normal flow of the game, when the ball is in play and both teams are trying to score.)
# * outfielder_block
#         - defender blocks a shot
# * pen_taken
#         - number of penalty kicks taken
# * penalty_won
#         - player fouled within the penalty box (excludes any penalties won for handball)
# * poss_lost_all
#         - total losses of possession
# * total_clearance
#         - total number of clearances
# * total_offside
#         - total number of offsides
# * total_pass
#         - total of all attempted (successful or unsuccessful) passes excluding throw-ins, keeper throws and crosses
# * total_pass_miss
#         - total of unsuccessful passes excluding throw-ins, keeper throws and crosses
# * total_through_ball
#         - total passes splitting the defense for a teammate to run on to
# * touches
#         - total sum of a player’s on-the-ball events
# * won_corners
#         - total corners forced by the player
# * fifty_fifty
#         - total number of a type of challenge between two players that allows equal chances of acquiring the control of the ball
# * successful_fifty_fifty
#         - won ball possession after being in fifty_fifty situation
# * yellow_card
#         - total number of yellow cards
# * duel
#         - total number of duels (A challenge between two players to gain control of the ball, progress with the ball or change its direction.)
# * duel_lost
#         - number of duels lost
# * duel_won
#         - number of duels won
# * aerial_duel
#         - number of duels when two players contest a ball in the air
# * ground_duel
#         - number of duels when two players contest a ball on the ground
# * times_tackled
#         - number of times player faced a tackle
# * interception
#         - a defending player intercepts a pass between opposition players
# * goals_conceded
#         - number of goals conceded
# * goals_conceded_ibox
#         - goal conceded from a shot inside the box
# * goals_conceded_obox
#         - goal conceded from a shot outside the box
# * saves
#         - total number of saves by the goalkeeper
# * saved_ibox
#         - shot saved from shot inside the box
# * saved_obox
#         - shot saved from shot outside the box
# * clean_sheet
#         - no goals conceded in the game (player must play 90 minutes)
# * accurate_goal_kicks
#         - number of goal kicks rached a teammate
# * dive_catch
#         - goalkeeper gains possession of the ball by diving towards the ball
# * inaccurate_goal_kicks
#         - number of goal kicks that don't reach teammate
# * penalty_faced
#         - goalkeeper faced a penalty kick
# * pen_goals_conceded
#         - conceded a goal after a penalty kick
# * punches
#         - goalkeeper punches the ball clear from a high ball
# * drops
#         - goalkeeper loses possession of the ball
# * good_claim
#         - goalkeeper intercepts oncoming cross and takes possession of the ball
# * saves_per
#         - goalkeeper saves percentage
# * goals_against_average
#         - the number of goals player allows for each unit of regulation game time. It is adjusted for the minutes player plays

# %% [markdown]
# #### Dataframe split
#
# For more precise results we have to split dataframe into 4 categories:
#
#     * Forwards
#     Players who play the furthest up the pitch therefore most responsible for scoring goals as well as assisting them.
#
#     * Midfielders
#     Midfielders often go across boundaries, with mobility and passing ability, they are often referred to as deep-lying midfielders, play-makers, box-to-box midfielders, or holding midfielders. Midfielders are assigned to disrupt the opposing team's attacks, while others may be tasked with creating goals, or have equal responsibilities between attack and defence. They are crucial and core of any team.
#
#     * Defenders
#     Players whose primary role is to stop attacks during the game and prevent the opposition from scoring.
#
#     * Goalkeepers
#     The goalkeeper's main role is to stop the opposing team from scoring (putting the ball over the goal-line of the goal). This is accomplished by having the goalkeeper move into the trajectory of the ball to either catch it or direct it further from the vicinity of the goal line.
#
# Since players have different roles on the field, we should compare their stats accordingly. Only within same category.

# %%
# Break down by position
forwards = stats[stats.position == 'Forward']
midfielders = stats[stats.position == 'Midfielder']
defenders = stats[stats.position == 'Defender']
goalkeepers = stats[stats.position == 'Goalkeeper']

print(len(forwards), len(midfielders), len(defenders), len(goalkeepers))
# Out:
# 130 220 199 74

# %% [markdown]
# #### Sample size
#
# Any sort of statistical analysis requires a minimum sample size. For example, a player who played only one game per season could have one shot on target and score one goal, resulting in a goal_conversion_per of 100%. On paper, this player would be the most efficient forward in the league, but in reality, the sample size is simply not big enough. To avoid such scenarios, we need to increase our sample size. To do so, we will filter out players who have played fewer than 765 minutes per season. 765 minutes is a 25% minimum threshold since the regular season has a total of 3060 regulation minutes (34 x 90).

# %%
# Filter out players with small sample size
forwards = forwards[forwards.mins >= 765].reset_index(drop=True)
midfielders = midfielders[midfielders.mins >= 765].reset_index(drop=True)
defenders = defenders[defenders.mins >= 765].reset_index(drop=True)
goalkeepers = goalkeepers[goalkeepers.mins >= 765].reset_index(drop=True)

# %% [markdown]
# #### Forwards
#
# To compare statistics for forwards, we will need to take a closer look at mainly attacking numbers, since it's their main role, along with some ball possession stats as well. Here they are:
#
#     - goal_conversion_per
#     - accurate_pass_per
#     - accurate_cross_per
#     - accurate_fwd_zone_pass_per
#     - tackle_success_per
#     - accurate_shooting_per
#
# The following stats are whole numbers for the season, but we need to adjust them based on the minutes spent on the field for each player or as a success percent:
#
#     - assist
#     - successful_dribble
#     - ball_recovery
#     - duel_won
#     - interception
#     - accurate_layoffs
#
# Most of the time penalty kikcs are done by designated shooters. Which means for majority of players this feature is not available, therefore we should adjust it relatevly to penalty kicks taken not minutes on the field.

# %%
# ADJUST NEEDED TO FORWARS STATS + LAYOFF
# Create minutes adjusted stats
midfielders['goal_conversion_per_min'] = midfielders['goal_conversion_per'] / midfielders['mins']
midfielders['accurate_pass_per_min'] = midfielders['accurate_pass_per'] / midfielders['mins']
midfielders['accurate_cross_per_min'] = midfielders['accurate_cross_per'] / midfielders['mins']
midfielders['accurate_fwd_zone_pass_per_min'] = midfielders['accurate_fwd_zone_pass_per'] / midfielders['mins']
midfielders['tackle_success_per_min'] = midfielders['tackle_success_per'] / midfielders['mins']
midfielders['accurate_shooting_per_min'] = midfielders['accurate_shooting_per'] / midfielders['mins']
midfielders['goals_min'] = midfielders['goals'] / midfielders['mins']
midfielders['assists_min'] = midfielders['assist'] / midfielders['mins']
midfielders['ball_recovery_min'] = midfielders['ball_recovery'] / midfielders['mins']
midfielders['interception_min'] = midfielders['interception'] / midfielders['mins']
midfielders['total_through_ball_min'] = midfielders['total_through_ball'] / midfielders['mins']
midfielders['won_corners_min'] = midfielders['won_corners'] / midfielders['mins']
# Calculate percetanges and minutes adjusted for those we don't have yet
# Dribbles
midfielders['total_dribbles'] = midfielders['successful_dribble'] + midfielders['failed_dribble']
midfielders['successful_dribble_per'] = midfielders['successful_dribble'] / midfielders['total_dribbles'] 
midfielders['successful_dribble_per_min'] = midfielders['successful_dribble_per'] / midfielders['mins']
# Back zone pass
midfielders['total_back_zone_pass'] = midfielders['accurate_back_zone_pass'] + midfielders['failed_back_zone_pass']
midfielders['accurate_back_zone_pass_per'] = midfielders['accurate_back_zone_pass'] / midfielders['total_back_zone_pass'] 
midfielders['accurate_back_zone_pass_per_min'] = midfielders['accurate_back_zone_pass_per'] / midfielders['mins']
# Duels
midfielders['duel_won_per'] = midfielders['duel_won'] / midfielders['duel']
midfielders['duel_won_per_min'] = midfielders['duel_won_per'] / midfielders['mins']
# Short pass
midfielders['total_short_pass'] = midfielders['successful_short_pass'] + midfielders['failed_short_pass']
midfielders['successful_short_pass_per'] = midfielders['successful_short_pass'] / midfielders['total_short_pass']
midfielders['successful_short_pass_per_min'] = midfielders['successful_short_pass_per'] / midfielders['mins']
# Long Balls
midfielders['total_long_balls'] = midfielders['accurate_long_balls'] + midfielders['failed_long_balls']
midfielders['accurate_long_balls_per'] = midfielders['accurate_long_balls'] / midfielders['total_long_balls']
midfielders['accurate_long_balls_per_min'] = midfielders['accurate_long_balls_per'] / midfielders['mins']
# Fifty-fifty
midfielders['successful_fifty_fifty_per'] = midfielders['successful_fifty_fifty'] / midfielders['fifty_fifty']
midfielders['successful_fifty_fifty_per_min'] = midfielders['successful_fifty_fifty_per'] / midfielders['mins']
# Penalty goal percent
midfielders['penalty_goal_per'] = midfielders['penalty_goal'] / midfielders['pen_taken']
midfielders['penalty_goal_per_min'] = midfielders['penalty_goal_per'] / midfielders['mins']
# Fill NaN with 0 for players who doesn't shoot penalties
midfielders['penalty_goal_per'] = midfielders['penalty_goal_per'].fillna(0)
midfielders['penalty_goal_per_min'] = midfielders['penalty_goal_per_min'].fillna(0)

forwards.head()
# Out:
#                    name club_abb                  club  2021 guaranteed comp.  \
# 0  Valentin Castellanos      NYC         New York City               776000.0
# 1            Ola Kamara       DC             DC United               420000.0
# 2      Javier Hernandez       LA             LA Galaxy              6000000.0
# 3          Raul Ruidiaz      SEA      Seattle Sounders              2100000.0
# 4         Daniel Salloi      SKC  Sporting Kansas City               456667.0
#
#    2022 guar. comp. position   birth_city birth_country  height, cm  \
# 0         1076000.0  Forward      Mendoza     Argentina       178.0
# 1         1520000.0  Forward          NaN           NaN       185.0
# 2         7443750.0  Forward  Guadalajara        Mexico       175.0
# 3         3201120.0  Forward         Lima          Peru       169.0
# 4          506667.0  Forward       Siófok       Hungary       185.0
#
#    weight, kg  ... good_claim  saves_per  goals_against_average  \
# 0        70.0  ...          0        0.0                   0.95
# 1        82.0  ...          0        0.0                   1.43
# 2        73.0  ...          0        0.0                   1.40
# 3        65.0  ...          0        0.0                   0.92
# 4        70.0  ...          0        0.0                   1.10
#
#    assists_per_min  successful_dribble_per_min  ball_recovery_per_min  \
# 0         0.002899                    0.010507               0.023913
# 1         0.002749                    0.002749               0.027488
# 2         0.001728                    0.008641               0.019585
# 3         0.000466                    0.008854               0.021901
# 4         0.003261                    0.010599               0.038728
#
#    duel_won_per_min  interception_per_min  accurate_layoffs_per_min  \
# 0          0.075000              0.001812                  0.015942
# 1          0.043430              0.003848                  0.008246
# 2          0.053571              0.002880                  0.016705
# 3          0.033085              0.001398                  0.015843
# 4          0.034651              0.005300                  0.011007
#
#    penalty_goal_per
# 0               0.8
# 1               0.9
# 2               0.5
# 3               0.8
# 4               0.0
#
# [5 rows x 116 columns]

# %% [markdown]
# ### Prediction model
# #### Scale data. Split data. Fit linear regression model.
#
#
#     - In order to perform regression prediction model we need to drop non numerical values from our dataset. As well drop the 2021 compensation since its based on previous performance. Check for missing data and fill in if possible.
#     - Then we need to scale data since some of our statistics values are on different scales.
#     - Split data into train and test datasets
#     - Fit model

# %%
# Missing data
# create a boolean dataframe indicating where there are NaN values
nan = forwards.isna()

# identify which columns have at least one NaN value
nan_cols = nan.any()

# print the column names with NaN values
print(nan_cols[nan_cols == True].index.tolist())
print(forwards['height, cm'].isna().value_counts())
print(forwards.loc[forwards['height, cm'].isna()==True])
print(forwards['weight, kg'].isna().value_counts())
print(forwards.loc[forwards['weight, kg'].isna()==True])
# Out:
# ['birth_city', 'birth_country', 'height, cm', 'weight, kg', 'foot']
# False    69
# True      1
# Name: height, cm, dtype: int64
#               name club_abb      club  2021 guaranteed comp.  \
# 44  Sunusi Ibrahim      MTL  Montreal               291250.0
#
#     2022 guar. comp. position birth_city birth_country  height, cm  \
# 44          291250.0  Forward      Keffi       Nigeria         NaN
#
#     weight, kg  ... good_claim  saves_per  goals_against_average  \
# 44         NaN  ...          0        0.0                    0.7
#
#     assists_per_min  successful_dribble_per_min  ball_recovery_per_min  \
# 44              0.0                    0.014396               0.035437
#
#     duel_won_per_min  interception_per_min  accurate_layoffs_per_min  \
# 44          0.063123              0.002215                  0.012182
#
#     penalty_goal_per
# 44               0.0
#
# [1 rows x 116 columns]
# False    68
# True      2
# Name: weight, kg, dtype: int64
#               name club_abb        club  2021 guaranteed comp.  \
# 44  Sunusi Ibrahim      MTL    Montreal               291250.0
# 62    Isaac Atanga      CIN  Cincinnati               273000.0
#
#     2022 guar. comp. position birth_city birth_country  height, cm  \
# 44          291250.0  Forward      Keffi       Nigeria         NaN
# 62          364000.0  Forward   Nkoranza         Ghana       173.0
#
#     weight, kg  ... good_claim  saves_per  goals_against_average  \
# 44         NaN  ...          0        0.0                   0.70
# 62         NaN  ...          0        0.0                   1.49
#
#     assists_per_min  successful_dribble_per_min  ball_recovery_per_min  \
# 44         0.000000                    0.014396               0.035437
# 62         0.001944                    0.011662               0.037901
#
#     duel_won_per_min  interception_per_min  accurate_layoffs_per_min  \
# 44          0.063123              0.002215                  0.012182
# 62          0.037901              0.003887                  0.003887
#
#     penalty_goal_per
# 44               0.0
# 62               0.0
#
# [2 rows x 116 columns]

# %%
# Height and weight is missing for Sunusi Ibrahim and only weight for Isaac Atanga. 
# Fill in this data by looking it up online.
forwards.loc[forwards['name'].str.contains('Sunusi Ibrahim'), 'height, cm'] = 168.0
forwards.loc[forwards['name'].str.contains('Sunusi Ibrahim'), 'weight, kg'] = 79.0
forwards.loc[forwards['name'].str.contains('Isaac Atanga'), 'weight, kg'] = 65.0

# %%
# Find non numerical columns
forwards.select_dtypes(include='object')
# Out:
#                     name club_abb                  club position   birth_city  \
# 0   Valentin Castellanos      NYC         New York City  Forward      Mendoza
# 1             Ola Kamara       DC             DC United  Forward          NaN
# 2       Javier Hernandez       LA             LA Galaxy  Forward  Guadalajara
# 3           Raul Ruidiaz      SEA      Seattle Sounders  Forward         Lima
# 4          Daniel Salloi      SKC  Sporting Kansas City  Forward       Siófok
# ..                   ...      ...                   ...      ...          ...
# 65        Chinonso Offor      CHI          Chicago Fire  Forward          Jos
# 66        Raheem Edwards     LAFC                  LAFC  Forward      Toronto
# 67        Fabian Herbers      CHI          Chicago Fire  Forward        Ahaus
# 68             Yuya Kubo      CIN            Cincinnati  Forward    Yamaguchi
# 69          Adrien Perez       DC             DC United  Forward          NaN
#
#    birth_country   foot
# 0      Argentina  Right
# 1            NaN    NaN
# 2         Mexico  Right
# 3           Peru  Right
# 4        Hungary   Both
# ..           ...    ...
# 65       Nigeria  Right
# 66        Canada    NaN
# 67       Germany    NaN
# 68         Japan  Right
# 69           NaN    NaN
#
# [70 rows x 7 columns]

# %%
# Get only numerical columns from our existing dataframe
fw_nums = forwards.drop(columns=['name', 'club_abb', 'club', '2021 guaranteed comp.', 'position', 'birth_city', 'birth_country', 'foot'])
columns = fw_nums.columns

# %%
# Scale the data
from sklearn.preprocessing import StandardScaler

# Instantiate standard scaler
scaler = StandardScaler()
# Fit transform data
array_nums_scaled = scaler.fit_transform(fw_nums)
# Creating scaled df
fw_nums_scaled = pd.DataFrame(array_nums_scaled, columns=columns)
print(fw_nums_scaled.head())
# Out:
#    2022 guar. comp.  height, cm  weight, kg  games_played  game_started  \
# 0         -0.072207   -0.136219   -0.640112      1.002002      1.985659
# 1          0.248804    0.803885    0.984342      0.344952      0.570220
# 2          4.531654   -0.539121   -0.233999     -0.804887      0.287132
# 3          1.464248   -1.344925   -1.316968      0.016426      0.853307
# 4         -0.483833    0.803885   -0.640112      0.673477      1.136395
#
#        mins    sub_on  total_sub_off  total_wins  total_losses  ...  \
# 0  1.987612 -1.414064       0.269852    1.077089      0.148910  ...
# 1  0.363567 -0.343962       0.704097    0.827432      0.403146  ...
# 2  0.220320 -1.235714      -0.815760   -0.171193     -0.868036  ...
# 3  0.927927 -1.057363      -1.467127    1.077089     -1.122272  ...
# 4  1.457769 -0.700663      -1.032882    1.326745     -0.105326  ...
#
#    good_claim  saves_per  goals_against_average  assists_per_min  \
# 0         0.0        0.0              -1.165459         0.487694
# 1         0.0        0.0               0.052185         0.381909
# 2         0.0        0.0              -0.023918        -0.338907
# 3         0.0        0.0              -1.241562        -1.230260
# 4         0.0        0.0              -0.784945         0.743887
#
#    successful_dribble_per_min  ball_recovery_per_min  duel_won_per_min  \
# 0                   -0.552702              -0.935677          0.767185
# 1                   -1.500665              -0.709387         -0.857013
# 2                   -0.780782              -1.209647         -0.335277
# 3                   -0.754741              -1.063036         -1.389278
# 4                   -0.541459               0.002190         -1.308678
#
#    interception_per_min  accurate_layoffs_per_min  penalty_goal_per
# 0             -0.805829                  1.319232          1.296661
# 1             -0.306168                 -0.169918          1.538168
# 2             -0.543670                  1.466883          0.572141
# 3             -0.907309                  1.300153          1.296661
# 4              0.049898                  0.364275         -0.635393
#
# [5 rows x 108 columns]

# %%
# Split data into test and train dataset
from sklearn.model_selection import train_test_split

# Select predictors
X = fw_nums_scaled[['height, cm', 'weight, kg',
       'goal_conversion_per', 'accurate_pass_per',
       'accurate_cross_per', 'accurate_fwd_zone_pass_per', 'tackle_success_per',
       'accurate_shooting_per', 'assists_per_min', 'successful_dribble_per_min',
       'ball_recovery_per_min', 'duel_won_per_min', 'interception_per_min',
       'accurate_layoffs_per_min', 'penalty_goal_per']]
# Select target variable
y = fw_nums_scaled[['2022 guar. comp.']]

# Split data
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)

# %%
# Fit model
from sklearn.linear_model import LinearRegression

# Ordinary Least Squares method
ols_all = LinearRegression()
# fit model
ols_all.fit(x_train,y_train)
# predict compensation on test data
comp_predict_all = ols_all.predict(x_test)
# R2 score (Residual Analysis)
print('All features Train score:')
print(ols_all.score(x_train,y_train))
print('All features Test score:')
print(ols_all.score(x_test,y_test))
# All features coef
print("All features coefficients:")
print(ols_all.coef_)
# Out:
# All features Train score:
# 0.3442501361809912
# All features Test score:
# 0.12513046068728118
# All features coefficients:
# [[-0.25802652  0.3573132   0.25120748  0.78015925 -0.14688946 -0.7032908
#    0.14041162 -0.20394594 -0.03999694  0.4776575  -0.38837313 -0.3927034
#    0.31945771  0.38399118  0.15357777]]

# %%
# Different features

# %%
# Select only positive coef predictors
X = fw_nums_scaled[['weight, kg','goal_conversion_per', 'accurate_pass_per','tackle_success_per', 
                    'successful_dribble_per_min', 'interception_per_min', 'accurate_layoffs_per_min', 
                    'penalty_goal_per']]
# Select target variable
y = fw_nums_scaled[['2022 guar. comp.']]

# Split data
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)

# Ordinary Least Squares method
ols_pc = LinearRegression()
# fit model
ols_pc.fit(x_train,y_train)
# predict compensation on test data
comp_predict_pc = ols_pc.predict(x_test)
# R2 score (Residual Analysis)
print('PC features Train score:')
print(ols_pc.score(x_train,y_train))
print('PC features Test score:')
print(ols_pc.score(x_test,y_test))
# PC features coef
print("PC features coefficients:")
print(ols_pc.coef_)
# Out:
# PC features Train score:
# 0.24778974902840412
# PC features Test score:
# -0.14474011155699507
# PC features coefficients:
# [[ 0.16320328  0.13820338  0.33451732 -0.02468896 -0.08564831 -0.08673988
#    0.04360107  0.22043146]]

# %%
# Select only positive coef predictors
X = fw_nums_scaled[['weight, kg',
       'goal_conversion_per', 'accurate_pass_per',
       'accurate_cross_per', 'tackle_success_per',
       'accurate_shooting_per', 'assists_per_min', 'successful_dribble_per_min',
       'ball_recovery_per_min', 'duel_won_per_min', 'interception_per_min',
       'accurate_layoffs_per_min']]
# Select target variable
y = fw_nums_scaled[['2022 guar. comp.']]

# Split data
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)

# Ordinary Least Squares method
ols_1 = LinearRegression()
# fit model
ols_1.fit(x_train,y_train)
# predict compensation on test data
comp_predict_pc = ols_1.predict(x_test)
# R2 score (Residual Analysis)
print('PC features Train score:')
print(ols_1.score(x_train,y_train))
print('PC features Test score:')
print(ols_1.score(x_test,y_test))
# PC features coef
print("PC features coefficients:")
print(ols_1.coef_)
# Out:
# PC features Train score:
# 0.4076703211568664
# PC features Test score:
# -0.10755612021493288
# PC features coefficients:
# [[ 0.24831511  0.1788393   0.18828806 -0.00124934  0.03463237 -0.27712187
#   -0.13407543  0.17431097 -0.19846068 -0.3713582   0.00305049  0.09749777]]

# %% [markdown]
# #### Distribution
#
# In order to be able to implement prediction model we need to make sure that data is normaly distributed. Let's check that.

# %%
# Distribution of compensation
# Set our variable
salary = forwards['2022 guar. comp.']
# Graph our compensation readings
plt.hist(salary, bins=70)
plt.xticks(rotation=45)
plt.title('Number of players by Compensation', size=16)
plt.ylabel('Number of players',size=12)
plt.xlabel('Guaranteed compensation',size=12)
plt.show()
plt.clf()

# %% [markdown]
# As we can see from the graph above compesation is not "normaly" distributed it is right-skewed histogram. With some outliers which are so called designated players. Since we want to predict compensation we have to use this feature, but model will struggle to pick up patterns for the players with high compensation (above 2 mil.) since there are only few of them and majority of players are under 2 mil.
#
# In order to address this issue we will try to scale this feature by using log transformation.

# %%
# Set our variable
log_salary = np.log(forwards['2022 guar. comp.'])
# Graph our compensation readings
plt.hist(log_salary, bins=70)
plt.xticks(rotation=45)
plt.title('Logarithm of Compensation', size=16)
plt.show()
plt.clf()

# %% [markdown]
# Now it looks more like "normal" distribution. Now we can try log-transformed compensation as target variable and see if model will perform better.

# %%
# Select predictors
X = fw_nums_scaled[['height, cm', 'weight, kg',
       'goal_conversion_per', 'accurate_pass_per',
       'accurate_cross_per', 'accurate_fwd_zone_pass_per', 'tackle_success_per',
       'accurate_shooting_per', 'assists_per_min', 'successful_dribble_per_min',
       'ball_recovery_per_min', 'duel_won_per_min', 'interception_per_min',
       'accurate_layoffs_per_min', 'penalty_goal_per']]
# Select target variable
y = log_salary

# Split data
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)
# Ordinary Least Squares method
ols_log = LinearRegression()
# fit model
ols_log.fit(x_train,y_train)
# predict compensation on test data
comp_predict_log = ols_log.predict(x_test)
# R2 score (Residual Analysis)
print('Y-log features Train score:')
print(ols_log.score(x_train,y_train))
print('Y-log features Test score:')
print(ols_log.score(x_test,y_test))
# PC features coef
print("Y-log features coefficients:")
print(ols_log.coef_)
# Out:
# Y-log features Train score:
# 0.4086056468142204
# Y-log features Test score:
# -0.017101688478440957
# Y-log features coefficients:
# [-0.12578655  0.29212639  0.05808901  0.40998338 -0.15985586 -0.19986078
#   0.22394253 -0.27585221 -0.16136857  0.39743993 -0.64487619 -0.34725715
#   0.33150024  0.19095755  0.28413152]

# %%
# Scale log_salary 
log_salary_reshaped = np.array(log_salary).reshape(-1,1)
log_salary_scaled = scaler.fit_transform(log_salary_reshaped)

# Select predictors
X = fw_nums_scaled[['height, cm', 'weight, kg',
       'goal_conversion_per', 'accurate_pass_per',
       'accurate_cross_per', 'accurate_fwd_zone_pass_per', 'tackle_success_per',
       'accurate_shooting_per', 'assists_per_min', 'successful_dribble_per_min',
       'ball_recovery_per_min', 'duel_won_per_min', 'interception_per_min',
       'accurate_layoffs_per_min', 'penalty_goal_per']]
# Select target variable
y = log_salary_scaled

# Split data
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)
# Ordinary Least Squares method
ols_log = LinearRegression()
# fit model
ols_log.fit(x_train,y_train)
# predict compensation on test data
comp_predict_log = ols_log.predict(x_test)
# R2 score (Residual Analysis)
print('Y-log features Train score:')
print(ols_log.score(x_train,y_train))
print('Y-log features Test score:')
print(ols_log.score(x_test,y_test))
# PC features coef
print("Y-log features coefficients:")
print(ols_log.coef_)
# Out:
# Y-log features Train score:
# 0.38682485916906617
# Y-log features Test score:
# -0.3477257866394108
# Y-log features coefficients:
# [[-0.22337626  0.24661682  0.16408114 -0.18130123 -0.149142    0.36884904
#   -0.0620236   0.01001375  0.07867422  0.3414208  -0.45378247 -0.21374584
#    0.20828742  0.28019879  0.14983733]]

# %%
# tackle,assist_per out
# Scale log_salary 
log_salary_reshaped = np.array(log_salary).reshape(-1,1)
log_salary_scaled = scaler.fit_transform(log_salary_reshaped)

# Select predictors tackle,assist_per out
X = fw_nums_scaled[['height, cm', 'weight, kg',
       'goal_conversion_per', 'accurate_pass_per',
       'accurate_cross_per', 'accurate_fwd_zone_pass_per',
       'accurate_shooting_per', 'successful_dribble_per_min',
       'ball_recovery_per_min', 'duel_won_per_min', 'interception_per_min',
       'accurate_layoffs_per_min', 'penalty_goal_per']]
# Select target variable
y = log_salary_scaled

# Split data
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)
# Ordinary Least Squares method
ols_log = LinearRegression()
# fit model
ols_log.fit(x_train,y_train)
# predict compensation on test data
comp_predict_log = ols_log.predict(x_test)
# R2 score (Residual Analysis)
print('Y-log features Train score:')
print(ols_log.score(x_train,y_train))
print('Y-log features Test score:')
print(ols_log.score(x_test,y_test))
# PC features coef
print("Y-log features coefficients:")
print(ols_log.coef_)
# Out:
# Y-log features Train score:
# 0.40340269017147357
# Y-log features Test score:
# 0.01782233880357431
# Y-log features coefficients:
# [[-0.15876042  0.14654305  0.2313532   0.66785072 -0.07270583 -0.63107659
#   -0.37884851  0.37720463 -0.65772196 -0.24740568  0.35949889  0.20283081
#    0.18649662]]

# %% [markdown]
# # TO BE CONTINUED...

# %% [markdown]
# #### Helper function to find each feature R2 scores

# %%
# Creation of help funtion to create linear regression model
def winnings_ols(feature):
    # Split the data into train and test parts
    X = fw_nums_scaled[[feature]]
    y = log_salary_scaled

    x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)
    # Ordinary Least Squares method
    ols = LinearRegression()
    # fit model
    ols.fit(x_train,y_train)
    # predict Winnings on test data
    comp_predict = ols.predict(x_test)
    # R2 score (Residual Analysis)
    print(str(feature) +  ' Train score:')
    print(ols.score(x_train,y_train))
    print(str(feature) + ' Test score:')
    print(ols.score(x_test,y_test))
    # Feature coef
    print(str(feature) +  ' coefficient:')
    print(ols.coef_)
    return feature, ols.score(x_test,y_test)

# Apply help function for every feature in the dataframe
dic=[]
for i in X.columns:
    dic.append(winnings_ols(i))
dic
# Out:
# height, cm Train score:
# 0.007312138290170189
# height, cm Test score:
# -0.12946175799782633
# height, cm coefficient:
# [[-0.08199328]]
# weight, kg Train score:
# 0.0071660749048870764
# weight, kg Test score:
# -0.09944860368009945
# weight, kg coefficient:
# [[0.08403603]]
# goal_conversion_per Train score:
# 0.09269127807870048
# goal_conversion_per Test score:
# -0.16800083172637637
# goal_conversion_per coefficient:
# [[0.30778599]]
# accurate_pass_per Train score:
# 0.02101027470483563
# accurate_pass_per Test score:
# -0.45668296546262255
# accurate_pass_per coefficient:
# [[0.13578976]]
# accurate_cross_per Train score:
# 0.00475372494699533
# accurate_cross_per Test score:
# -0.07330589640017027
# accurate_cross_per coefficient:
# [[-0.07054599]]
# accurate_fwd_zone_pass_per Train score:
# 0.014339423004515517
# accurate_fwd_zone_pass_per Test score:
# 0.0171103059109472
# accurate_fwd_zone_pass_per coefficient:
# [[0.11365403]]
# accurate_shooting_per Train score:
# 0.0010723205617595433
# accurate_shooting_per Test score:
# -0.005663520435486014
# accurate_shooting_per coefficient:
# [[-0.03107265]]
# successful_dribble_per_min Train score:
# 0.008328988072105359
# successful_dribble_per_min Test score:
# 0.05319717747871888
# successful_dribble_per_min coefficient:
# [[-0.09742151]]
# ball_recovery_per_min Train score:
# 0.07540043600478474
# ball_recovery_per_min Test score:
# 0.10136197047661122
# ball_recovery_per_min coefficient:
# [[-0.27633065]]
# duel_won_per_min Train score:
# 0.07440812604142566
# duel_won_per_min Test score:
# 0.01978800587151408
# duel_won_per_min coefficient:
# [[-0.27580182]]
# interception_per_min Train score:
# 0.024232015094810544
# interception_per_min Test score:
# 0.09778115899484485
# interception_per_min coefficient:
# [[-0.14986041]]
# accurate_layoffs_per_min Train score:
# 0.04981156107100482
# accurate_layoffs_per_min Test score:
# -0.7471440142765449
# accurate_layoffs_per_min coefficient:
# [[0.21106039]]
# penalty_goal_per Train score:
# 0.09652376852320077
# penalty_goal_per Test score:
# 0.29014160346974793
# penalty_goal_per coefficient:
# [[0.33138901]]
# [('height, cm', -0.12946175799782633),
#  ('weight, kg', -0.09944860368009945),
#  ('goal_conversion_per', -0.16800083172637637),
#  ('accurate_pass_per', -0.45668296546262255),
#  ('accurate_cross_per', -0.07330589640017027),
#  ('accurate_fwd_zone_pass_per', 0.0171103059109472),
#  ('accurate_shooting_per', -0.005663520435486014),
#  ('successful_dribble_per_min', 0.05319717747871888),
#  ('ball_recovery_per_min', 0.10136197047661122),
#  ('duel_won_per_min', 0.01978800587151408),
#  ('interception_per_min', 0.09778115899484485),
#  ('accurate_layoffs_per_min', -0.7471440142765449),
#  ('penalty_goal_per', 0.29014160346974793)]

# %%
for i in X.columns:
    feature = X[i]
    # Graph our compensation readings
    plt.hist(feature, bins=70)
    plt.xticks(rotation=45)
    plt.title(i, size=16)
    plt.show()
    plt.clf()

# %%
# Height and Weight out
# Scale log_salary 
log_salary_reshaped = np.array(log_salary).reshape(-1,1)
log_salary_scaled = scaler.fit_transform(log_salary_reshaped)

# Select predictors tackle,assist_per out
X = fw_nums_scaled[['goal_conversion_per', 'accurate_pass_per',
       'accurate_cross_per', 'accurate_fwd_zone_pass_per',
       'accurate_shooting_per', 'successful_dribble_per_min',
       'ball_recovery_per_min', 'duel_won_per_min', 'interception_per_min',
       'accurate_layoffs_per_min', 'penalty_goal_per']]
# Select target variable
y = log_salary_scaled

# Split data
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)
# Ordinary Least Squares method
ols_log = LinearRegression()
# fit model
ols_log.fit(x_train,y_train)
# predict compensation on test data
comp_predict_log = ols_log.predict(x_test)
# R2 score (Residual Analysis)
print('Y-log features Train score:')
print(ols_log.score(x_train,y_train))
print('Y-log features Test score:')
print(ols_log.score(x_test,y_test))
# PC features coef
print("Y-log features coefficients:")
print(ols_log.coef_)
# Out:
# Y-log features Train score:
# 0.42028218091238
# Y-log features Test score:
# -0.5182373282657309
# Y-log features coefficients:
# [[ 0.12543709  0.46291585 -0.17951292 -0.36693526 -0.25962604  0.36343362
#   -0.56204487 -0.33190714  0.28326387  0.22128063  0.30341279]]

# %%
# Height and Weight and accurate_fwd_zone_pass_per, 'accurate_cross_per' out
# Scale log_salary 
log_salary_reshaped = np.array(log_salary).reshape(-1,1)
log_salary_scaled = scaler.fit_transform(log_salary_reshaped)

# Select predictors tackle,assist_per out
X = fw_nums_scaled[['goal_conversion_per', 'accurate_pass_per',
        
       'accurate_shooting_per', 'successful_dribble_per_min',
       'ball_recovery_per_min', 'duel_won_per_min', 'interception_per_min',
       'accurate_layoffs_per_min', 'penalty_goal_per']]
# Select target variable
y = log_salary_scaled

# Split data
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)
# Ordinary Least Squares method
ols_log = LinearRegression()
# fit model
ols_log.fit(x_train,y_train)
# predict compensation on test data
comp_predict_log = ols_log.predict(x_test)
# R2 score (Residual Analysis)
print('Y-log features Train score:')
print(ols_log.score(x_train,y_train))
print('Y-log features Test score:')
print(ols_log.score(x_test,y_test))
# PC features coef
print("Y-log features coefficients:")
print(ols_log.coef_)
# Out:
# Y-log features Train score:
# 0.3898810038872169
# Y-log features Test score:
# -1.2903821781305318
# Y-log features coefficients:
# [[ 0.0885294   0.18857873 -0.10046567  0.33880118 -0.60175632 -0.22824419
#    0.22808339  0.36250077  0.33661849]]

# %% [markdown]
# #### Lasso regression

# %%
# Height and Weight and accurate_fwd_zone_pass_per, 'accurate_cross_per' out
from sklearn.linear_model import Lasso
# Select predictors
X = fw_nums_scaled[['goal_conversion_per', 'accurate_pass_per',
        
       'accurate_shooting_per', 'successful_dribble_per_min',
       'ball_recovery_per_min', 'duel_won_per_min', 'interception_per_min',
       'accurate_layoffs_per_min', 'penalty_goal_per']]
# Select target variable
y = log_salary_scaled
# Split data
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)
# Lasso regression
lasso = Lasso(alpha=0.05)
# Fit model
lasso.fit(x_train, y_train)
# Predict compensation on test data
comp_predict_log = lasso.predict(x_test)
# R2 score
print('Lasso Train score:')
print(lasso.score(x_train, y_train))
print('Lasso Test score:')
print(lasso.score(x_test, y_test))
# Lasso coefficients
print("Lasso coefficients:")
print(lasso.coef_)
# Out:
# Lasso Train score:
# 0.34158187491846137
# Lasso Test score:
# -0.2887345599955622
# Lasso coefficients:
# [ 0.13127769  0.19312194 -0.          0.10051001 -0.32324964 -0.12285156
#  -0.          0.04045096  0.15814153]

# %% [markdown]
# #### Ridge regression

# %%
# Height and Weight and accurate_fwd_zone_pass_per, 'accurate_cross_per' out
from sklearn.linear_model import Ridge
# Select predictors
X = fw_nums_scaled[['goal_conversion_per', 'accurate_pass_per',
        
       'accurate_shooting_per', 'successful_dribble_per_min',
       'ball_recovery_per_min', 'duel_won_per_min', 'interception_per_min',
       'accurate_layoffs_per_min', 'penalty_goal_per']]
# Select target variable
y = log_salary_scaled
# Split data
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)
# Ridge regression
ridge = Ridge(alpha=0.1)
# Fit model
ridge.fit(x_train, y_train)
# Predict compensation on test data
comp_predict_log = ridge.predict(x_test)
# R2 scores
print('Ridge Train score:')
print(ridge.score(x_train, y_train))
print('Ridge Test score:')
print(ridge.score(x_test, y_test))
# Ridge coefficients
print("Ridge coefficients:")
print(ridge.coef_)
# Out:
# Ridge Train score:
# 0.3295271742686895
# Ridge Test score:
# 0.09047312907942462
# Ridge coefficients:
# [[ 0.12937113  0.1218914  -0.13913575  0.42368921 -0.32841193 -0.19636352
#    0.03411763  0.28126836  0.26823609]]

# %% [markdown]
# #### Elastic Net

# %%
from sklearn.linear_model import ElasticNet

# Scale log_salary 
log_salary_reshaped = np.array(log_salary).reshape(-1,1)
log_salary_scaled = scaler.fit_transform(log_salary_reshaped)

# Select predictors
X = fw_nums_scaled[['height, cm', 'weight, kg',
       'goal_conversion_per', 'accurate_pass_per',
       'accurate_cross_per', 'accurate_fwd_zone_pass_per', 'tackle_success_per',
       'accurate_shooting_per', 'assists_per_min', 'successful_dribble_per_min',
       'ball_recovery_per_min', 'duel_won_per_min', 'interception_per_min',
       'accurate_layoffs_per_min', 'penalty_goal_per']]

# Select target variable
y = log_salary_scaled

# Split data
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2)

# Elastic Net method
enet = ElasticNet(alpha=0.1, l1_ratio=0.5)
# Fit model
enet.fit(x_train, y_train)
# Predict compensation on test data
comp_predict_log = enet.predict(x_test)

# R2 score (Residual Analysis)
print('Y-log features Train score:')
print(enet.score(x_train,y_train))
print('Y-log features Test score:')
print(enet.score(x_test,y_test))

# Elastic Net coefficients
print("Y-log features coefficients:")
print(enet.coef_)
# Out:
# Y-log features Train score:
# 0.2727210697007413
# Y-log features Test score:
# 0.2733658009779064
# Y-log features coefficients:
# [-0.          0.01134505  0.00148504  0.20703315 -0.08832922  0.03020843
#   0.0059966  -0.0416342  -0.00682112  0.         -0.28626481 -0.01453406
#   0.          0.03883359  0.20364278]

# %% [markdown]
# #### Gradient Boosting Regression

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Select predictors
X = fw_nums_scaled[['height, cm', 'weight, kg',
       'goal_conversion_per', 'accurate_pass_per',
       'accurate_cross_per', 'accurate_fwd_zone_pass_per', 'tackle_success_per',
       'accurate_shooting_per', 'assists_per_min', 'successful_dribble_per_min',
       'ball_recovery_per_min', 'duel_won_per_min', 'interception_per_min',
       'accurate_layoffs_per_min', 'penalty_goal_per']]
# Select target variable
y = log_salary_scaled.ravel()

# Split data
x_train, x_test, y_train, y_test = train_test_split(X,y, train_size=0.8, test_size=0.2)

# Initialize the Gradient Boosting Regressor
gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=0, loss='ls')

# Train the model
gbr.fit(x_train, y_train)

# Predict compensation on test data
comp_predict_log = gbr.predict(x_test)

# R2 score (Residual Analysis)
print('Y-log features Train score:')
print(gbr.score(x_train,y_train))
print('Y-log features Test score:')
print(gbr.score(x_test,y_test))

# Feature importance
print("Feature importance:")
print(gbr.feature_importances_)
# Out:
# Y-log features Train score:
# 0.9999999939214654
# Y-log features Test score:
# -0.03610240666896236
# Feature importance:
# [3.93033192e-02 2.08941448e-02 5.93978334e-02 1.01579940e-01
#  1.50373711e-01 2.05214086e-02 6.91162611e-02 3.57780793e-02
#  1.81095853e-02 1.03769178e-01 1.90919552e-01 1.05290755e-01
#  3.56768104e-02 4.90826898e-02 1.86732141e-04]
